# %% [markdown]
# ## ML2 - Session 1 - Practice

# %% [markdown]
# ## Tesla is devaloping a self driving car that can autonomously navigate the road. They need to devalop an ML model that can recognize the different traffic signs, pedestrians, traffic lights, obstacles, cars and road lines. The ML model is complex so the devlopment team are trying to get a good accuracy to identify the different objects.
# <img style="float: center; /"  width = "1000"  src="Notebook Images/ML-M2-Session1-Practice-Image1.png">
#
# ## Your task is to train a KNN model on the traffic sign dataset using the pixel features. Use 5000 images from the dataset and then add more to see how much its affecting the training time and accuracy of the model.
# ## The following are the 43 classes of the dataset:
# <img style="float: center; /"  width = "1000"  src="Notebook Images/ML-M2-Session1-Practice-Image2.png">
#
# ## What you need to do:
# 1. Load & show from the traffic sign dataset:<br>
#     1.1 Load and show 5000 images <br>
#     1.2 Load 10000 images <br>
# 2. Create, train, test & evaluate a KNN model using three values for k = [3, 5, 10] for each of the following data sizes:<br>
#     2.1 5000 images <br>
#     2.2 10000 images <br>

# %% [markdown]
# ### 1. Load & show from the traffic sign dataset

# %% [markdown]
# ### 1.1 5000 images

# %% [markdown]
# 1.1.1 Load 5000 from the traffic sign dataset. filename = "traffic_sign." To specify the number of images to load use the function __*load(filename, nbr_of_images)*__ ex: data_5000 = load("traffic_sign", 5000)

# %%
data_5000 = load("traffic_sign", 5000)

# %% [markdown]
# 1.1.2 Show the dataset in a table format

# %%
show(data_5000)
# Out:
# Showing the first 10 rows
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Image</th>
#       <th>ClassName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Speed limit (80km/h)</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Speed limit (120km/h)</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Go straight or right</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Turn right ahead</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Speed limit (80km/h)</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Priority road</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Stop</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>End of no passing</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>No passing</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Right-of-way at the next intersection</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 1.2 10000 images

# %% [markdown]
# 1.2.1 Load 10000 from the traffic sign dataset

# %%
data_10000 = load("traffic_sign", 10000)

# %% [markdown]
# ### 2. Create, train, test & evaluate a KNN model using three values for k = [3, 5, 10] for each subset

# %% [markdown]
# ### 2.1 5000 images

# %% [markdown]
# 2.1.1 Split the dataset into training and testing data using the __*split\_table(data)*__ function. ex: train_5000, test_5000 = split_table(data_5000)

# %%
train_5000, test_5000 = split_table(data_5000)

# %% [markdown]
# 2.1.2 Train a KNN model for each value of k, test & evaluate the model by showing the classification report. Use a timer to record the execution time for the training. Use the functions __*start\_timer()*__ to start the timer and __*end\_timer()*__ to end the timer and show the time.<br><br> ex:
# start_timer() <br>
# fit_model(model, train_2000, "ClassName", "Image")<br>
# end_timer()

# %%
neighbors = [3, 5, 10]
for k in neighbors:
    # Create the KNN model 
    model = create_model("knn", k)
    # Train the model & record the time
    start_timer()
    fit_model(model, train_5000, "ClassName", "Image")
    end_timer()
    # Check the accuracy of the model
    check_accuracy(model, test_5000)
    # Show the classifcation report
    show_classification_report(model, test_5000)
# Out:
# Execution Time: 1.3383934497833252 seconds
# For k = 3
# Accuracy score of the model is: 57.9 %
#
#
# For k = 3
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ahead only</th>
#       <td>0.571429</td>
#       <td>0.888889</td>
#     </tr>
#     <tr>
#       <th>Beware of ice/snow</th>
#       <td>0.458333</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <th>Bicycles crossing</th>
#       <td>0.333333</td>
#       <td>0.285714</td>
#     </tr>
#     <tr>
#       <th>Bumpy road</th>
#       <td>0.363636</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <th>Children crossing</th>
#       <td>0.384615</td>
#       <td>0.555556</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the left</th>
#       <td>0.666667</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the right</th>
#       <td>0.307692</td>
#       <td>0.444444</td>
#     </tr>
#     <tr>
#       <th>Double curve</th>
#       <td>0.400000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>End of all speed and passing limits</th>
#       <td>0.428571</td>
#       <td>0.428571</td>
#     </tr>
#     <tr>
#       <th>End of no passing</th>
#       <td>0.545455</td>
#       <td>0.857143</td>
#     </tr>
#     <tr>
#       <th>End of no passing by vehicles over 3.5 metric tons</th>
#       <td>1.000000</td>
#       <td>0.714286</td>
#     </tr>
#     <tr>
#       <th>End of speed limit (80km/h)</th>
#       <td>0.700000</td>
#       <td>0.636364</td>
#     </tr>
#     <tr>
#       <th>General caution</th>
#       <td>0.342105</td>
#       <td>0.448276</td>
#     </tr>
#     <tr>
#       <th>Go straight or left</th>
#       <td>0.900000</td>
#       <td>0.818182</td>
#     </tr>
#     <tr>
#       <th>Go straight or right</th>
#       <td>0.611111</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <th>Keep left</th>
#       <td>1.000000</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <th>Keep right</th>
#       <td>0.566667</td>
#       <td>0.641509</td>
#     </tr>
#     <tr>
#       <th>No entry</th>
#       <td>0.750000</td>
#       <td>0.774194</td>
#     </tr>
#     <tr>
#       <th>No passing</th>
#       <td>0.644444</td>
#       <td>0.674419</td>
#     </tr>
#     <tr>
#       <th>No passing for vehicles over 3.5 metric tons</th>
#       <td>0.629032</td>
#       <td>0.735849</td>
#     </tr>
#     <tr>
#       <th>No vehicles</th>
#       <td>0.437500</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Pedestrians</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Priority road</th>
#       <td>0.660714</td>
#       <td>0.685185</td>
#     </tr>
#     <tr>
#       <th>Right-of-way at the next intersection</th>
#       <td>0.689655</td>
#       <td>0.588235</td>
#     </tr>
#     <tr>
#       <th>Road narrows on the right</th>
#       <td>1.000000</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <th>Road work</th>
#       <td>0.611111</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Roundabout mandatory</th>
#       <td>0.714286</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Slippery road</th>
#       <td>0.875000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (100km/h)</th>
#       <td>0.319149</td>
#       <td>0.535714</td>
#     </tr>
#     <tr>
#       <th>Speed limit (120km/h)</th>
#       <td>0.576923</td>
#       <td>0.652174</td>
#     </tr>
#     <tr>
#       <th>Speed limit (20km/h)</th>
#       <td>0.600000</td>
#       <td>0.428571</td>
#     </tr>
#     <tr>
#       <th>Speed limit (30km/h)</th>
#       <td>0.563636</td>
#       <td>0.462687</td>
#     </tr>
#     <tr>
#       <th>Speed limit (50km/h)</th>
#       <td>0.478261</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (60km/h)</th>
#       <td>0.619048</td>
#       <td>0.406250</td>
#     </tr>
#     <tr>
#       <th>Speed limit (70km/h)</th>
#       <td>0.594595</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (80km/h)</th>
#       <td>0.459459</td>
#       <td>0.395349</td>
#     </tr>
#     <tr>
#       <th>Stop</th>
#       <td>0.933333</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <th>Traffic signals</th>
#       <td>0.500000</td>
#       <td>0.214286</td>
#     </tr>
#     <tr>
#       <th>Turn left ahead</th>
#       <td>0.800000</td>
#       <td>0.800000</td>
#     </tr>
#     <tr>
#       <th>Turn right ahead</th>
#       <td>0.666667</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <th>Vehicles over 3.5 metric tons prohibited</th>
#       <td>0.588235</td>
#       <td>0.769231</td>
#     </tr>
#     <tr>
#       <th>Wild animals crossing</th>
#       <td>0.324324</td>
#       <td>0.923077</td>
#     </tr>
#     <tr>
#       <th>Yield</th>
#       <td>0.953488</td>
#       <td>0.661290</td>
#     </tr>
#   </tbody>
# </table>
# Execution Time: 1.3423306941986084 seconds
# For k = 5
# Accuracy score of the model is: 53.6 %
#
#
# For k = 5
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ahead only</th>
#       <td>0.424242</td>
#       <td>0.777778</td>
#     </tr>
#     <tr>
#       <th>Beware of ice/snow</th>
#       <td>0.409091</td>
#       <td>0.692308</td>
#     </tr>
#     <tr>
#       <th>Bicycles crossing</th>
#       <td>0.250000</td>
#       <td>0.285714</td>
#     </tr>
#     <tr>
#       <th>Bumpy road</th>
#       <td>0.333333</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <th>Children crossing</th>
#       <td>0.235294</td>
#       <td>0.444444</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the left</th>
#       <td>0.500000</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the right</th>
#       <td>0.266667</td>
#       <td>0.444444</td>
#     </tr>
#     <tr>
#       <th>Double curve</th>
#       <td>0.200000</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <th>End of all speed and passing limits</th>
#       <td>0.375000</td>
#       <td>0.428571</td>
#     </tr>
#     <tr>
#       <th>End of no passing</th>
#       <td>0.600000</td>
#       <td>0.428571</td>
#     </tr>
#     <tr>
#       <th>End of no passing by vehicles over 3.5 metric tons</th>
#       <td>0.750000</td>
#       <td>0.428571</td>
#     </tr>
#     <tr>
#       <th>End of speed limit (80km/h)</th>
#       <td>0.666667</td>
#       <td>0.545455</td>
#     </tr>
#     <tr>
#       <th>General caution</th>
#       <td>0.266667</td>
#       <td>0.413793</td>
#     </tr>
#     <tr>
#       <th>Go straight or left</th>
#       <td>1.000000</td>
#       <td>0.545455</td>
#     </tr>
#     <tr>
#       <th>Go straight or right</th>
#       <td>0.666667</td>
#       <td>0.615385</td>
#     </tr>
#     <tr>
#       <th>Keep left</th>
#       <td>1.000000</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <th>Keep right</th>
#       <td>0.515625</td>
#       <td>0.622642</td>
#     </tr>
#     <tr>
#       <th>No entry</th>
#       <td>0.800000</td>
#       <td>0.774194</td>
#     </tr>
#     <tr>
#       <th>No passing</th>
#       <td>0.722222</td>
#       <td>0.604651</td>
#     </tr>
#     <tr>
#       <th>No passing for vehicles over 3.5 metric tons</th>
#       <td>0.627119</td>
#       <td>0.698113</td>
#     </tr>
#     <tr>
#       <th>No vehicles</th>
#       <td>0.454545</td>
#       <td>0.357143</td>
#     </tr>
#     <tr>
#       <th>Pedestrians</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Priority road</th>
#       <td>0.625000</td>
#       <td>0.648148</td>
#     </tr>
#     <tr>
#       <th>Right-of-way at the next intersection</th>
#       <td>0.727273</td>
#       <td>0.470588</td>
#     </tr>
#     <tr>
#       <th>Road narrows on the right</th>
#       <td>1.000000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Road work</th>
#       <td>0.476190</td>
#       <td>0.454545</td>
#     </tr>
#     <tr>
#       <th>Roundabout mandatory</th>
#       <td>0.833333</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Slippery road</th>
#       <td>0.750000</td>
#       <td>0.428571</td>
#     </tr>
#     <tr>
#       <th>Speed limit (100km/h)</th>
#       <td>0.318182</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (120km/h)</th>
#       <td>0.528302</td>
#       <td>0.608696</td>
#     </tr>
#     <tr>
#       <th>Speed limit (20km/h)</th>
#       <td>0.666667</td>
#       <td>0.285714</td>
#     </tr>
#     <tr>
#       <th>Speed limit (30km/h)</th>
#       <td>0.634615</td>
#       <td>0.492537</td>
#     </tr>
#     <tr>
#       <th>Speed limit (50km/h)</th>
#       <td>0.500000</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (60km/h)</th>
#       <td>0.636364</td>
#       <td>0.437500</td>
#     </tr>
#     <tr>
#       <th>Speed limit (70km/h)</th>
#       <td>0.489362</td>
#       <td>0.522727</td>
#     </tr>
#     <tr>
#       <th>Speed limit (80km/h)</th>
#       <td>0.420000</td>
#       <td>0.488372</td>
#     </tr>
#     <tr>
#       <th>Stop</th>
#       <td>1.000000</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <th>Traffic signals</th>
#       <td>0.400000</td>
#       <td>0.142857</td>
#     </tr>
#     <tr>
#       <th>Turn left ahead</th>
#       <td>0.800000</td>
#       <td>0.800000</td>
#     </tr>
#     <tr>
#       <th>Turn right ahead</th>
#       <td>0.750000</td>
#       <td>0.187500</td>
#     </tr>
#     <tr>
#       <th>Vehicles over 3.5 metric tons prohibited</th>
#       <td>0.615385</td>
#       <td>0.615385</td>
#     </tr>
#     <tr>
#       <th>Wild animals crossing</th>
#       <td>0.229167</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <th>Yield</th>
#       <td>0.816327</td>
#       <td>0.645161</td>
#     </tr>
#   </tbody>
# </table>
# Execution Time: 1.3399953842163086 seconds
# For k = 10
# Accuracy score of the model is: 49.0 %
#
#
# For k = 10
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ahead only</th>
#       <td>0.361111</td>
#       <td>0.722222</td>
#     </tr>
#     <tr>
#       <th>Beware of ice/snow</th>
#       <td>0.411765</td>
#       <td>0.538462</td>
#     </tr>
#     <tr>
#       <th>Bicycles crossing</th>
#       <td>0.333333</td>
#       <td>0.285714</td>
#     </tr>
#     <tr>
#       <th>Bumpy road</th>
#       <td>0.181818</td>
#       <td>0.166667</td>
#     </tr>
#     <tr>
#       <th>Children crossing</th>
#       <td>0.277778</td>
#       <td>0.555556</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the left</th>
#       <td>0.250000</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the right</th>
#       <td>0.153846</td>
#       <td>0.222222</td>
#     </tr>
#     <tr>
#       <th>Double curve</th>
#       <td>0.250000</td>
#       <td>0.125000</td>
#     </tr>
#     <tr>
#       <th>End of all speed and passing limits</th>
#       <td>0.428571</td>
#       <td>0.428571</td>
#     </tr>
#     <tr>
#       <th>End of no passing</th>
#       <td>0.600000</td>
#       <td>0.428571</td>
#     </tr>
#     <tr>
#       <th>End of no passing by vehicles over 3.5 metric tons</th>
#       <td>1.000000</td>
#       <td>0.285714</td>
#     </tr>
#     <tr>
#       <th>End of speed limit (80km/h)</th>
#       <td>0.285714</td>
#       <td>0.181818</td>
#     </tr>
#     <tr>
#       <th>General caution</th>
#       <td>0.250000</td>
#       <td>0.448276</td>
#     </tr>
#     <tr>
#       <th>Go straight or left</th>
#       <td>0.800000</td>
#       <td>0.363636</td>
#     </tr>
#     <tr>
#       <th>Go straight or right</th>
#       <td>0.800000</td>
#       <td>0.615385</td>
#     </tr>
#     <tr>
#       <th>Keep left</th>
#       <td>1.000000</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <th>Keep right</th>
#       <td>0.534247</td>
#       <td>0.735849</td>
#     </tr>
#     <tr>
#       <th>No entry</th>
#       <td>0.846154</td>
#       <td>0.709677</td>
#     </tr>
#     <tr>
#       <th>No passing</th>
#       <td>0.571429</td>
#       <td>0.558140</td>
#     </tr>
#     <tr>
#       <th>No passing for vehicles over 3.5 metric tons</th>
#       <td>0.631579</td>
#       <td>0.679245</td>
#     </tr>
#     <tr>
#       <th>No vehicles</th>
#       <td>0.600000</td>
#       <td>0.214286</td>
#     </tr>
#     <tr>
#       <th>Pedestrians</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Priority road</th>
#       <td>0.508197</td>
#       <td>0.574074</td>
#     </tr>
#     <tr>
#       <th>Right-of-way at the next intersection</th>
#       <td>0.541667</td>
#       <td>0.382353</td>
#     </tr>
#     <tr>
#       <th>Road narrows on the right</th>
#       <td>1.000000</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <th>Road work</th>
#       <td>0.522727</td>
#       <td>0.522727</td>
#     </tr>
#     <tr>
#       <th>Roundabout mandatory</th>
#       <td>0.625000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Slippery road</th>
#       <td>0.500000</td>
#       <td>0.142857</td>
#     </tr>
#     <tr>
#       <th>Speed limit (100km/h)</th>
#       <td>0.333333</td>
#       <td>0.535714</td>
#     </tr>
#     <tr>
#       <th>Speed limit (120km/h)</th>
#       <td>0.457627</td>
#       <td>0.586957</td>
#     </tr>
#     <tr>
#       <th>Speed limit (20km/h)</th>
#       <td>1.000000</td>
#       <td>0.142857</td>
#     </tr>
#     <tr>
#       <th>Speed limit (30km/h)</th>
#       <td>0.653061</td>
#       <td>0.477612</td>
#     </tr>
#     <tr>
#       <th>Speed limit (50km/h)</th>
#       <td>0.514286</td>
#       <td>0.327273</td>
#     </tr>
#     <tr>
#       <th>Speed limit (60km/h)</th>
#       <td>0.454545</td>
#       <td>0.312500</td>
#     </tr>
#     <tr>
#       <th>Speed limit (70km/h)</th>
#       <td>0.391304</td>
#       <td>0.409091</td>
#     </tr>
#     <tr>
#       <th>Speed limit (80km/h)</th>
#       <td>0.370968</td>
#       <td>0.534884</td>
#     </tr>
#     <tr>
#       <th>Stop</th>
#       <td>1.000000</td>
#       <td>0.476190</td>
#     </tr>
#     <tr>
#       <th>Traffic signals</th>
#       <td>0.166667</td>
#       <td>0.071429</td>
#     </tr>
#     <tr>
#       <th>Turn left ahead</th>
#       <td>0.500000</td>
#       <td>0.200000</td>
#     </tr>
#     <tr>
#       <th>Turn right ahead</th>
#       <td>1.000000</td>
#       <td>0.187500</td>
#     </tr>
#     <tr>
#       <th>Vehicles over 3.5 metric tons prohibited</th>
#       <td>0.700000</td>
#       <td>0.538462</td>
#     </tr>
#     <tr>
#       <th>Wild animals crossing</th>
#       <td>0.250000</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <th>Yield</th>
#       <td>0.694915</td>
#       <td>0.661290</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2.2 10000 images

# %% [markdown]
# 2.2.1 Split the dataset

# %%
train_10000, test_10000 = split_table(data_10000)

# %% [markdown]
# 2.2.2 Train a KNN model for each value of k, test & evaluate the model by showing the classification report.

# %%
neighbors = [3, 5, 10]
for k in neighbors:
    # Create the KNN model 
    model = create_model("knn", k)
    # Train the model & record the time
    start_timer()
    fit_model(model, train_10000, "ClassName", "Image")
    end_timer()
    # Check the accuracy of the model
    check_accuracy(model, test_10000)
    # Show the classifcation report
    show_classification_report(model, test_10000)
# Out:
# Execution Time: 2.7241673469543457 seconds
# For k = 3
# Accuracy score of the model is: 72.85000000000001 %
#
#
# For k = 3
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ahead only</th>
#       <td>0.746667</td>
#       <td>0.861538</td>
#     </tr>
#     <tr>
#       <th>Beware of ice/snow</th>
#       <td>0.694444</td>
#       <td>0.925926</td>
#     </tr>
#     <tr>
#       <th>Bicycles crossing</th>
#       <td>0.478261</td>
#       <td>0.611111</td>
#     </tr>
#     <tr>
#       <th>Bumpy road</th>
#       <td>0.521739</td>
#       <td>0.750000</td>
#     </tr>
#     <tr>
#       <th>Children crossing</th>
#       <td>0.884615</td>
#       <td>0.884615</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the left</th>
#       <td>0.789474</td>
#       <td>0.937500</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the right</th>
#       <td>0.384615</td>
#       <td>0.416667</td>
#     </tr>
#     <tr>
#       <th>Double curve</th>
#       <td>0.857143</td>
#       <td>0.600000</td>
#     </tr>
#     <tr>
#       <th>End of all speed and passing limits</th>
#       <td>0.750000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>End of no passing</th>
#       <td>0.857143</td>
#       <td>0.750000</td>
#     </tr>
#     <tr>
#       <th>End of no passing by vehicles over 3.5 metric tons</th>
#       <td>0.909091</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>End of speed limit (80km/h)</th>
#       <td>0.833333</td>
#       <td>0.909091</td>
#     </tr>
#     <tr>
#       <th>General caution</th>
#       <td>0.523810</td>
#       <td>0.709677</td>
#     </tr>
#     <tr>
#       <th>Go straight or left</th>
#       <td>0.600000</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <th>Go straight or right</th>
#       <td>0.500000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Keep left</th>
#       <td>1.000000</td>
#       <td>0.944444</td>
#     </tr>
#     <tr>
#       <th>Keep right</th>
#       <td>0.708029</td>
#       <td>0.858407</td>
#     </tr>
#     <tr>
#       <th>No entry</th>
#       <td>0.870370</td>
#       <td>0.854545</td>
#     </tr>
#     <tr>
#       <th>No passing</th>
#       <td>0.753623</td>
#       <td>0.650000</td>
#     </tr>
#     <tr>
#       <th>No passing for vehicles over 3.5 metric tons</th>
#       <td>0.720930</td>
#       <td>0.877358</td>
#     </tr>
#     <tr>
#       <th>No vehicles</th>
#       <td>0.696970</td>
#       <td>0.741935</td>
#     </tr>
#     <tr>
#       <th>Pedestrians</th>
#       <td>0.692308</td>
#       <td>0.692308</td>
#     </tr>
#     <tr>
#       <th>Priority road</th>
#       <td>0.844444</td>
#       <td>0.760000</td>
#     </tr>
#     <tr>
#       <th>Right-of-way at the next intersection</th>
#       <td>0.733333</td>
#       <td>0.550000</td>
#     </tr>
#     <tr>
#       <th>Road narrows on the right</th>
#       <td>0.909091</td>
#       <td>0.714286</td>
#     </tr>
#     <tr>
#       <th>Road work</th>
#       <td>0.692308</td>
#       <td>0.542169</td>
#     </tr>
#     <tr>
#       <th>Roundabout mandatory</th>
#       <td>0.666667</td>
#       <td>0.555556</td>
#     </tr>
#     <tr>
#       <th>Slippery road</th>
#       <td>0.866667</td>
#       <td>0.650000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (100km/h)</th>
#       <td>0.500000</td>
#       <td>0.742857</td>
#     </tr>
#     <tr>
#       <th>Speed limit (120km/h)</th>
#       <td>0.717647</td>
#       <td>0.772152</td>
#     </tr>
#     <tr>
#       <th>Speed limit (20km/h)</th>
#       <td>0.714286</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (30km/h)</th>
#       <td>0.750000</td>
#       <td>0.735849</td>
#     </tr>
#     <tr>
#       <th>Speed limit (50km/h)</th>
#       <td>0.684783</td>
#       <td>0.617647</td>
#     </tr>
#     <tr>
#       <th>Speed limit (60km/h)</th>
#       <td>0.803922</td>
#       <td>0.546667</td>
#     </tr>
#     <tr>
#       <th>Speed limit (70km/h)</th>
#       <td>0.704545</td>
#       <td>0.632653</td>
#     </tr>
#     <tr>
#       <th>Speed limit (80km/h)</th>
#       <td>0.630435</td>
#       <td>0.674419</td>
#     </tr>
#     <tr>
#       <th>Stop</th>
#       <td>0.964286</td>
#       <td>0.675000</td>
#     </tr>
#     <tr>
#       <th>Traffic signals</th>
#       <td>0.884615</td>
#       <td>0.741935</td>
#     </tr>
#     <tr>
#       <th>Turn left ahead</th>
#       <td>0.736842</td>
#       <td>0.538462</td>
#     </tr>
#     <tr>
#       <th>Turn right ahead</th>
#       <td>1.000000</td>
#       <td>0.724138</td>
#     </tr>
#     <tr>
#       <th>Vehicles over 3.5 metric tons prohibited</th>
#       <td>0.916667</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>Wild animals crossing</th>
#       <td>0.647059</td>
#       <td>0.825000</td>
#     </tr>
#     <tr>
#       <th>Yield</th>
#       <td>0.913462</td>
#       <td>0.818966</td>
#     </tr>
#   </tbody>
# </table>
# Execution Time: 2.7252118587493896 seconds
# For k = 5
# Accuracy score of the model is: 67.25 %
#
#
# For k = 5
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ahead only</th>
#       <td>0.690141</td>
#       <td>0.753846</td>
#     </tr>
#     <tr>
#       <th>Beware of ice/snow</th>
#       <td>0.606061</td>
#       <td>0.740741</td>
#     </tr>
#     <tr>
#       <th>Bicycles crossing</th>
#       <td>0.444444</td>
#       <td>0.444444</td>
#     </tr>
#     <tr>
#       <th>Bumpy road</th>
#       <td>0.478261</td>
#       <td>0.687500</td>
#     </tr>
#     <tr>
#       <th>Children crossing</th>
#       <td>0.760000</td>
#       <td>0.730769</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the left</th>
#       <td>0.714286</td>
#       <td>0.937500</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the right</th>
#       <td>0.625000</td>
#       <td>0.416667</td>
#     </tr>
#     <tr>
#       <th>Double curve</th>
#       <td>0.769231</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>End of all speed and passing limits</th>
#       <td>0.800000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>End of no passing</th>
#       <td>0.571429</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>End of no passing by vehicles over 3.5 metric tons</th>
#       <td>0.818182</td>
#       <td>0.900000</td>
#     </tr>
#     <tr>
#       <th>End of speed limit (80km/h)</th>
#       <td>0.794118</td>
#       <td>0.818182</td>
#     </tr>
#     <tr>
#       <th>General caution</th>
#       <td>0.542169</td>
#       <td>0.725806</td>
#     </tr>
#     <tr>
#       <th>Go straight or left</th>
#       <td>0.625000</td>
#       <td>0.555556</td>
#     </tr>
#     <tr>
#       <th>Go straight or right</th>
#       <td>0.800000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Keep left</th>
#       <td>1.000000</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <th>Keep right</th>
#       <td>0.718519</td>
#       <td>0.858407</td>
#     </tr>
#     <tr>
#       <th>No entry</th>
#       <td>0.901961</td>
#       <td>0.836364</td>
#     </tr>
#     <tr>
#       <th>No passing</th>
#       <td>0.800000</td>
#       <td>0.600000</td>
#     </tr>
#     <tr>
#       <th>No passing for vehicles over 3.5 metric tons</th>
#       <td>0.692308</td>
#       <td>0.849057</td>
#     </tr>
#     <tr>
#       <th>No vehicles</th>
#       <td>0.689655</td>
#       <td>0.645161</td>
#     </tr>
#     <tr>
#       <th>Pedestrians</th>
#       <td>0.666667</td>
#       <td>0.461538</td>
#     </tr>
#     <tr>
#       <th>Priority road</th>
#       <td>0.869048</td>
#       <td>0.730000</td>
#     </tr>
#     <tr>
#       <th>Right-of-way at the next intersection</th>
#       <td>0.754098</td>
#       <td>0.575000</td>
#     </tr>
#     <tr>
#       <th>Road narrows on the right</th>
#       <td>1.000000</td>
#       <td>0.714286</td>
#     </tr>
#     <tr>
#       <th>Road work</th>
#       <td>0.577465</td>
#       <td>0.493976</td>
#     </tr>
#     <tr>
#       <th>Roundabout mandatory</th>
#       <td>0.615385</td>
#       <td>0.444444</td>
#     </tr>
#     <tr>
#       <th>Slippery road</th>
#       <td>0.714286</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (100km/h)</th>
#       <td>0.475728</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (120km/h)</th>
#       <td>0.583333</td>
#       <td>0.708861</td>
#     </tr>
#     <tr>
#       <th>Speed limit (20km/h)</th>
#       <td>0.833333</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (30km/h)</th>
#       <td>0.707071</td>
#       <td>0.660377</td>
#     </tr>
#     <tr>
#       <th>Speed limit (50km/h)</th>
#       <td>0.574468</td>
#       <td>0.529412</td>
#     </tr>
#     <tr>
#       <th>Speed limit (60km/h)</th>
#       <td>0.616667</td>
#       <td>0.493333</td>
#     </tr>
#     <tr>
#       <th>Speed limit (70km/h)</th>
#       <td>0.595745</td>
#       <td>0.571429</td>
#     </tr>
#     <tr>
#       <th>Speed limit (80km/h)</th>
#       <td>0.457627</td>
#       <td>0.627907</td>
#     </tr>
#     <tr>
#       <th>Stop</th>
#       <td>0.925926</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <th>Traffic signals</th>
#       <td>0.826087</td>
#       <td>0.612903</td>
#     </tr>
#     <tr>
#       <th>Turn left ahead</th>
#       <td>0.800000</td>
#       <td>0.461538</td>
#     </tr>
#     <tr>
#       <th>Turn right ahead</th>
#       <td>0.826087</td>
#       <td>0.655172</td>
#     </tr>
#     <tr>
#       <th>Vehicles over 3.5 metric tons prohibited</th>
#       <td>0.692308</td>
#       <td>0.818182</td>
#     </tr>
#     <tr>
#       <th>Wild animals crossing</th>
#       <td>0.550000</td>
#       <td>0.825000</td>
#     </tr>
#     <tr>
#       <th>Yield</th>
#       <td>0.857143</td>
#       <td>0.775862</td>
#     </tr>
#   </tbody>
# </table>
# Execution Time: 2.7351694107055664 seconds
# For k = 10
# Accuracy score of the model is: 59.85 %
#
#
# For k = 10
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ahead only</th>
#       <td>0.705882</td>
#       <td>0.738462</td>
#     </tr>
#     <tr>
#       <th>Beware of ice/snow</th>
#       <td>0.653846</td>
#       <td>0.629630</td>
#     </tr>
#     <tr>
#       <th>Bicycles crossing</th>
#       <td>0.454545</td>
#       <td>0.277778</td>
#     </tr>
#     <tr>
#       <th>Bumpy road</th>
#       <td>0.384615</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <th>Children crossing</th>
#       <td>0.666667</td>
#       <td>0.692308</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the left</th>
#       <td>0.736842</td>
#       <td>0.875000</td>
#     </tr>
#     <tr>
#       <th>Dangerous curve to the right</th>
#       <td>0.571429</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <th>Double curve</th>
#       <td>1.000000</td>
#       <td>0.350000</td>
#     </tr>
#     <tr>
#       <th>End of all speed and passing limits</th>
#       <td>0.625000</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <th>End of no passing</th>
#       <td>0.454545</td>
#       <td>0.312500</td>
#     </tr>
#     <tr>
#       <th>End of no passing by vehicles over 3.5 metric tons</th>
#       <td>0.700000</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <th>End of speed limit (80km/h)</th>
#       <td>0.764706</td>
#       <td>0.787879</td>
#     </tr>
#     <tr>
#       <th>General caution</th>
#       <td>0.414634</td>
#       <td>0.548387</td>
#     </tr>
#     <tr>
#       <th>Go straight or left</th>
#       <td>0.333333</td>
#       <td>0.222222</td>
#     </tr>
#     <tr>
#       <th>Go straight or right</th>
#       <td>0.800000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Keep left</th>
#       <td>1.000000</td>
#       <td>0.722222</td>
#     </tr>
#     <tr>
#       <th>Keep right</th>
#       <td>0.608108</td>
#       <td>0.796460</td>
#     </tr>
#     <tr>
#       <th>No entry</th>
#       <td>0.956522</td>
#       <td>0.800000</td>
#     </tr>
#     <tr>
#       <th>No passing</th>
#       <td>0.732143</td>
#       <td>0.512500</td>
#     </tr>
#     <tr>
#       <th>No passing for vehicles over 3.5 metric tons</th>
#       <td>0.649254</td>
#       <td>0.820755</td>
#     </tr>
#     <tr>
#       <th>No vehicles</th>
#       <td>0.680000</td>
#       <td>0.548387</td>
#     </tr>
#     <tr>
#       <th>Pedestrians</th>
#       <td>0.666667</td>
#       <td>0.307692</td>
#     </tr>
#     <tr>
#       <th>Priority road</th>
#       <td>0.760870</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <th>Right-of-way at the next intersection</th>
#       <td>0.703704</td>
#       <td>0.475000</td>
#     </tr>
#     <tr>
#       <th>Road narrows on the right</th>
#       <td>0.818182</td>
#       <td>0.642857</td>
#     </tr>
#     <tr>
#       <th>Road work</th>
#       <td>0.440476</td>
#       <td>0.445783</td>
#     </tr>
#     <tr>
#       <th>Roundabout mandatory</th>
#       <td>0.500000</td>
#       <td>0.444444</td>
#     </tr>
#     <tr>
#       <th>Slippery road</th>
#       <td>0.500000</td>
#       <td>0.350000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (100km/h)</th>
#       <td>0.356522</td>
#       <td>0.585714</td>
#     </tr>
#     <tr>
#       <th>Speed limit (120km/h)</th>
#       <td>0.565217</td>
#       <td>0.658228</td>
#     </tr>
#     <tr>
#       <th>Speed limit (20km/h)</th>
#       <td>0.750000</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (30km/h)</th>
#       <td>0.636364</td>
#       <td>0.594340</td>
#     </tr>
#     <tr>
#       <th>Speed limit (50km/h)</th>
#       <td>0.500000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (60km/h)</th>
#       <td>0.550000</td>
#       <td>0.440000</td>
#     </tr>
#     <tr>
#       <th>Speed limit (70km/h)</th>
#       <td>0.560976</td>
#       <td>0.469388</td>
#     </tr>
#     <tr>
#       <th>Speed limit (80km/h)</th>
#       <td>0.369231</td>
#       <td>0.558140</td>
#     </tr>
#     <tr>
#       <th>Stop</th>
#       <td>0.958333</td>
#       <td>0.575000</td>
#     </tr>
#     <tr>
#       <th>Traffic signals</th>
#       <td>0.739130</td>
#       <td>0.548387</td>
#     </tr>
#     <tr>
#       <th>Turn left ahead</th>
#       <td>0.833333</td>
#       <td>0.384615</td>
#     </tr>
#     <tr>
#       <th>Turn right ahead</th>
#       <td>0.761905</td>
#       <td>0.551724</td>
#     </tr>
#     <tr>
#       <th>Vehicles over 3.5 metric tons prohibited</th>
#       <td>0.777778</td>
#       <td>0.636364</td>
#     </tr>
#     <tr>
#       <th>Wild animals crossing</th>
#       <td>0.352113</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <th>Yield</th>
#       <td>0.843137</td>
#       <td>0.741379</td>
#     </tr>
#   </tbody>
# </table>
