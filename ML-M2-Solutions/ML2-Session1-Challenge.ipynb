# %% [markdown]
# # ML2 - Session 1 - Challenge

# %% [markdown]
# ## A team of researchers are trying to develop a machine that can diagnose brain tumors for patients based on x-ray scans of their brains. They are hoping that the machine can help doctors diagnose correctly in order to treat the patients with brain tumors as fast as possible.
# ## The problem is very critical, so the team are taking their time to find the best ML model that gives the highest possible accuracy so that the amount of false positives and true negatives are minimal.
# <img style="float: center; /"  width = "1000"  src="Notebook Images/ML-M2-Session1-Challenge-Image1.png">
#
# ## Your task is to train a KNN model that can classify an xray scan image as healthy or with Brain Tumor.
# <img style="float: center; /"  width = "500"  src="Notebook Images/ML-M2-Session1-Challenge-Image2.png">
#
# ## What you need to do:
# 1. Load & show from the brain tumor dataset: <br>
#     1.1 Load and show 500 images
#     1.2 Load 1000 images <br>
#     1.3 Load 4600 images (Full dataset) <br>
# 2. Create, train, test & evaluate a KNN model using three values for k = [3, 5, 10] for each of the following data sizes:<br>
#     2.1 500 images <br>
#     2.2 1000 images <br>
#     2.3 4600 images <br>

# %% [markdown]
# ### 1. Load & show from the brain tumor dataset

# %% [markdown]
# ### 1.1 500 images

# %% [markdown]
# 1.1.1 Load 500 images from the brain tumor dataset. filename = brain_tumor

# %%
data_500 = load("brain_tumor", 500)

# %% [markdown]
# 1.1.2 Show the dataset

# %%
show(data_500)
# Out:
# Showing the first 10 rows
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Image</th>
#       <th>ClassName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 1.2 1000 images

# %% [markdown]
# 1.2.1 Load 1000 images from the brain tumor dataset

# %%
data_1000 = load("brain_tumor",1000)

# %% [markdown]
# 1.2.2 Show the dataset

# %%
show(data_1000)
# Out:
# Showing the first 10 rows
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Image</th>
#       <th>ClassName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 1.3 4600 images

# %% [markdown]
# 1.3.1 Load 4600 images from the brain tumor dataset

# %%
data = load("brain_tumor",4600)

# %% [markdown]
# 1.3.2 Show the dataset

# %%
show(data)
# Out:
# Showing the first 10 rows
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Image</th>
#       <th>ClassName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Brain Tumor</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>Healthy</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2. Create, train, test & evaluate a KNN model using three values for k = [3, 5, 10] for each subset

# %% [markdown]
# ### 2.1 500 images

# %% [markdown]
# 2.1.1 Split the dataset

# %%
train_500, test_500 = split_table(data_500)

# %% [markdown]
# 2.1.2 Train a KNN model for each value of k, test & evaluate the model by showing the classification report. Use a timer to record the execution time for the training.

# %%
neighbors = [3, 5, 10]
for k in neighbors:
    # Create the KNN model
    model = create_model("knn", k)
    # Train the model
    start_timer()
    fit_model(model, train_500, "ClassName", "Image")
    end_timer()
    # Check the accuracy of the model
    check_accuracy(model, test_500)
    # Show the classifciation report
    show_classification_report(model, test_500)
# Out:
# Execution Time: 0.8146069049835205 seconds
# For k = 3
# Accuracy score of the model is: 75.0 %
#
#
# For k = 3
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Brain Tumor</th>
#       <td>0.897436</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <th>Healthy</th>
#       <td>0.655738</td>
#       <td>0.909091</td>
#     </tr>
#   </tbody>
# </table>
# Execution Time: 0.8441548347473145 seconds
# For k = 5
# Accuracy score of the model is: 74.0 %
#
#
# For k = 5
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Brain Tumor</th>
#       <td>0.857143</td>
#       <td>0.642857</td>
#     </tr>
#     <tr>
#       <th>Healthy</th>
#       <td>0.655172</td>
#       <td>0.863636</td>
#     </tr>
#   </tbody>
# </table>
# Execution Time: 0.7901616096496582 seconds
# For k = 10
# Accuracy score of the model is: 75.0 %
#
#
# For k = 10
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Brain Tumor</th>
#       <td>0.816327</td>
#       <td>0.714286</td>
#     </tr>
#     <tr>
#       <th>Healthy</th>
#       <td>0.686275</td>
#       <td>0.795455</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2.2 1000 images

# %% [markdown]
# 2.2.1 Split the dataset

# %%
train_1000, test_1000 = split_table(data_1000)

# %% [markdown]
# 2.2.2 Train a KNN model for each value of k, test & evaluate the model by showing the classification report. Use a timer to record the execution time for the training.

# %%
neighbors = [3, 5, 10]
for k in neighbors:
    # Create the KNN model
    model = create_model("knn", k)
    # Train the model
    start_timer()
    fit_model(model, train_1000, "ClassName", "Image")
    end_timer()
    # Check the accuracy of the model
    check_accuracy(model, test_1000)
    # Show the classifciation report
    show_classification_report(model, test_1000)
# Out:
# Execution Time: 1.5380632877349854 seconds
# For k = 3
# Accuracy score of the model is: 82.5 %
#
#
# For k = 3
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Brain Tumor</th>
#       <td>0.841584</td>
#       <td>0.817308</td>
#     </tr>
#     <tr>
#       <th>Healthy</th>
#       <td>0.808081</td>
#       <td>0.833333</td>
#     </tr>
#   </tbody>
# </table>
# Execution Time: 1.5969345569610596 seconds
# For k = 5
# Accuracy score of the model is: 80.0 %
#
#
# For k = 5
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Brain Tumor</th>
#       <td>0.826531</td>
#       <td>0.778846</td>
#     </tr>
#     <tr>
#       <th>Healthy</th>
#       <td>0.774510</td>
#       <td>0.822917</td>
#     </tr>
#   </tbody>
# </table>
# Execution Time: 1.57120943069458 seconds
# For k = 10
# Accuracy score of the model is: 75.0 %
#
#
# For k = 10
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Brain Tumor</th>
#       <td>0.77</td>
#       <td>0.740385</td>
#     </tr>
#     <tr>
#       <th>Healthy</th>
#       <td>0.73</td>
#       <td>0.760417</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2.3 4600 images

# %% [markdown]
# 2.3.1 Split the dataset

# %%
train_data, test_data = split_table(data)

# %% [markdown]
# 2.3.2 Train a KNN model for each value of k, test & evaluate the model by showing the classification report. Use a timer to record the execution time for the training.

# %%
neighbors = [3,5,10]
for k in neighbors:
    # Create the KNN model
    model = create_model("knn", k)  
    # Train the model
    start_timer()
    fit_model(model, train_data, "ClassName", "Image")
    end_timer()
    # Check the accuracy of the model
    check_accuracy(model, test_data)
    # Show the classifciation report
    show_classification_report(model, test_data)
# Out:
# Execution Time: 7.0715391635894775 seconds
# For k = 3
# Accuracy score of the model is: 92.3913043478261 %
#
#
# For k = 3
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Brain Tumor</th>
#       <td>0.950397</td>
#       <td>0.914122</td>
#     </tr>
#     <tr>
#       <th>Healthy</th>
#       <td>0.891827</td>
#       <td>0.936869</td>
#     </tr>
#   </tbody>
# </table>
# Execution Time: 6.896950006484985 seconds
# For k = 5
# Accuracy score of the model is: 90.43478260869566 %
#
#
# For k = 5
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Brain Tumor</th>
#       <td>0.946721</td>
#       <td>0.881679</td>
#     </tr>
#     <tr>
#       <th>Healthy</th>
#       <td>0.856481</td>
#       <td>0.934343</td>
#     </tr>
#   </tbody>
# </table>
# Execution Time: 6.987144470214844 seconds
# For k = 10
# Accuracy score of the model is: 86.95652173913044 %
#
#
# For k = 10
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Brain Tumor</th>
#       <td>0.910569</td>
#       <td>0.854962</td>
#     </tr>
#     <tr>
#       <th>Healthy</th>
#       <td>0.822430</td>
#       <td>0.888889</td>
#     </tr>
#   </tbody>
# </table>
