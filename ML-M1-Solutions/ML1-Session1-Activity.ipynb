# %% [markdown]
# # ML1 - Session 1 - Class Activity

# %% [markdown]
# # Fruit Nutrition Application

# %% [markdown]
# ## A team of software developers are trying to create a machine learning application that can list the nutritonal benefits of a fruit using a picture. The team figured they can train and use a machine learning model to determine the fruit type and list its benefits.
# ## They found that two of the features they can use are the width and height of the fruit however they don't have the proper ML model to seperate the classes. They want to perform testing with at least apples and bananas before they can work with other fruits.
# <img style="float: center; /"  width = "1000"  src="Notebook Images/ML-M1-Session1-ClassActivity-Image.png">
#
# ## Your task is to help the team seperate the apples and bananas classes. You need to show the data in a table and a scatter plot and show that you can seperate the two fruits with a line on the plot.

# %% [markdown]
# ## Activity - Part 1
# ### What you need to do:
#
# 1. Load the apples and bananas dataset
# 2. Show the data using:<br>
#     1.1 A table <br>
#     1.2 A scatter plot<br>

# %% [markdown]
# ### 1. Load the apples and bananas dataset

# %% [markdown]
# 1.1 Load the data using the __*load(filename)*__ function where filneame is the name of the dataset. Store the loaded data in a variable. The filename for the dataset is: "applesandbananas_simple"
#     ex: data = load("example_name")
# <br> The CSV file looks like this:
#
# ![lesson1_excel.JPG](attachment:lesson1_excel.JPG)

# %%
data = load("applesandbananas_simple")

# %% [markdown]
# ### 2. Show the data

# %% [markdown]
# 2.1 Show the data in table format on Jupyter using the __*show(data, number_of_rows)*__ function where:
#  - *data* is the variable used to store the dataset
#  - *number_of_rows* is the number of rows to show from the dataset.
# ex: show(data, 20) will show 20 rows from the dataset stored in data. The number of rows parameter is optional, the default number of rows is 10.

# %%
show(data)
# Out:
# Showing the first 10 rows
# ...

# %% [markdown]
# 2.2 Plot the data in a scatter plot using the __*plot\_scatter(data)*__ function. ex: plot_scatter(data)

# %% [markdown]
# ## Activity - Part 2
# ### What you need to do:
# 3. Split the dataset into training and testing
# 4. Draw a line between the two classes

# %% [markdown]
# ### 3. Split the dataset into training and testing

# %% [markdown]
# 3.1 Split the dataset using the __*split\_table(data)*__ function. The split_table returns two values training data and testing data. ex: train_data, test_data = split_table(data)

# %%
train_data, test_data = split_table(data)

# %% [markdown]
# ### 4. Draw a line between the two classes

# %% [markdown]
# 4.1 Demonstrate the line that can be drawn between the two fruits using the function __*draw\_line(data, x1, y1, x2, y2)*__. ex: draw_line(data, 3,4,4.5,7)

# %%
draw_line(data, 3,4,4.5,7)
